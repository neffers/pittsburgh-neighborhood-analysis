# %% [markdown]
# # Crash Data
#
# The dataset that I decided to choose was the crash dataset. I feel that is important to note, however, that this dataset also includes deaths and injuries that are caused by vehicles. In a good neighborhood there would be fewer deaths, injuries, and crashes overall.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
township_data = pd.read_csv('township-key.csv')
township_data
# Out:
#      Code                    Policy Agency
# 0    2101                 Baldwin Township
# 1    2102                 Collier Township
# 2    2103                 Cresent Township
# 3    2104               East Deer Township
# 4    2105               Elizabeth Township
# ..    ...                              ...
# 121  2506         University Of Pittsburgh
# 122  2507           Chatham College Police
# 123  2508              Duquesne University
# 124  2509         Robert Morris University
# 125  2601   Allegheny County Sheriffs Dept
#
# [126 rows x 2 columns]

# %%
crash_data = pd.read_csv('crash-data-cumulative.csv')
crash_data
# Out:
# /opt/tljh/user/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (19,20,73,77,78,79,80,81,82,83,84,183,189) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          CRASH_CRN  DISTRICT  CRASH_COUNTY  MUNICIPALITY POLICE_AGCY  \
# 0       2004000001        11             2          2454       02454
# 1       2004000010        11             2          2440       02440
# 2       2004000016        11             2          2203       02203
# 3       2004000022        11             2          2404       02404
# 4       2004000030        11             2          2419       02419
# ...            ...       ...           ...           ...         ...
# 204893  2021017633        11             2          2116       02116
# 204894  2021018779        11             2          2464       00000
# ...

# %%
crash_data['MUNICIPALITY'].min()
# Out:
# 2101

# %%
township_data['Policy Agency']
# Out:
# 0                     Baldwin Township
# 1                     Collier Township
# 2                     Cresent Township
# 3                   East Deer Township
# 4                   Elizabeth Township
#                     ...
# 121           University Of Pittsburgh
# 122             Chatham College Police
# 123                Duquesne University
# 124           Robert Morris University
# 125     Allegheny County Sheriffs Dept
# Name: Policy Agency, Length: 126, dtype: object

# %%
for index, row in crash_data.iterrows():
    for index, row_two in township_data.iterrows():
        if row[3] == row_two[0]:
            row[3] = row_two[1]
            break
crash_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6fee0bd922a3> in <module>
#       1 for index, row in crash_data.iterrows():
# ----> 2     for index, row_two in township_data.iterrows():
#       3         if row[3] == row_two[0]:
#       4             row[3] = row_two[1]
#       5             break
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/frame.py in iterrows(self)
#     950         klass = self._constructor_sliced
#     951         for k, v in zip(self.index, self.values):
# --> 952             s = klass(v, index=columns, name=k)
#     953             yield k, s
#     954
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     303                     data = data.copy()
#     304             else:
# ...
